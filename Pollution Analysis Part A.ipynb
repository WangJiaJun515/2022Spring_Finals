# %%
# import the necessary libraries
import matplotlib
import numpy as np
import pandas as pd
import os

# Visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import chart_studio.plotly as py

# Increase the default plot size and set the color scheme
plt.rcParams['figure.figsize'] = 12, 8
plt.style.use("fivethirtyeight")# for pretty graphs

import folium
from folium.plugins import HeatMap
# import matplotlib as plt

# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# %%
us_pollution = pd.read_csv('pollution_2000_2021.csv')

# %%
us_pollution
# Out:
#               Date  Year  Month  Day                                  Address  \
# 0       2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1       2000-01-02  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2       2000-01-03  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3       2000-01-04  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4       2000-01-05  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# ...            ...   ...    ...  ...                                      ...
# 608694  2021-06-26  2021      6   26    NCore - North Cheyenne Soccer Complex
# 608695  2021-06-27  2021      6   27    NCore - North Cheyenne Soccer Complex
# 608696  2021-06-28  2021      6   28    NCore - North Cheyenne Soccer Complex
# 608697  2021-06-29  2021      6   29    NCore - North Cheyenne Soccer Complex
# 608698  2021-06-30  2021      6   30    NCore - North Cheyenne Soccer Complex
#
#           State    County           City   O3 Mean  O3 1st Max Value  ...  \
# 0       Arizona  Maricopa        Phoenix  0.019765             0.040  ...
# 1       Arizona  Maricopa        Phoenix  0.015882             0.032  ...
# 2       Arizona  Maricopa        Phoenix  0.009353             0.016  ...
# 3       Arizona  Maricopa        Phoenix  0.015882             0.033  ...
# 4       Arizona  Maricopa        Phoenix  0.007353             0.012  ...
# ...         ...       ...            ...       ...               ...  ...
# 608694  Wyoming   Laramie  Not in a city  0.040588             0.049  ...
# 608695  Wyoming   Laramie  Not in a city  0.037882             0.042  ...
# 608696  Wyoming   Laramie  Not in a city  0.039765             0.050  ...
# 608697  Wyoming   Laramie  Not in a city  0.049176             0.058  ...
# 608698  Wyoming   Laramie  Not in a city  0.052333             0.054  ...
#
#         CO 1st Max Hour  CO AQI  SO2 Mean  SO2 1st Max Value  \
# 0                    23    25.0  3.000000                9.0
# 1                     0    26.0  1.958333                3.0
# 2                     8    28.0  5.250000               11.0
# 3                    23    34.0  7.083333               16.0
# 4                     2    42.0  8.708333               15.0
# ...                 ...     ...       ...                ...
# 608694                0     1.0  0.409091                0.7
# 608695                0     1.0  0.325000                0.4
# 608696                0     1.0  0.326087                0.5
# 608697                0     1.0  0.317391                0.5
# 608698                0     1.0  0.366667                0.5
#
#         SO2 1st Max Hour  SO2 AQI   NO2 Mean  NO2 1st Max Value  \
# 0                     21     13.0  19.041667               49.0
# 1                     22      4.0  22.958333               36.0
# 2                     19     16.0  38.125000               51.0
# 3                      8     23.0  40.260870               74.0
# 4                      7     21.0  48.450000               61.0
# ...                  ...      ...        ...                ...
# 608694                 2      0.0   1.281818                2.1
# 608695                 4      0.0   1.104167                2.3
# 608696                 2      0.0   1.678261                5.8
# 608697                20      0.0   2.934783                7.4
# 608698                 3      0.0   2.762500                7.5
#
#         NO2 1st Max Hour  NO2 AQI
# 0                     19       46
# 1                     19       34
# 2                      8       48
# 3                      8       72
# 4                     22       58
# ...                  ...      ...
# 608694                 0        2
# 608695                20        2
# 608696                23        5
# 608697                 0        7
# 608698                 5        7
#
# [608699 rows x 24 columns]

# %%
us_pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608699 entries, 0 to 608698
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               608699 non-null  object
#  1   Year               608699 non-null  int64
#  2   Month              608699 non-null  int64
#  3   Day                608699 non-null  int64
#  4   Address            608699 non-null  object
#  5   State              608699 non-null  object
#  6   County             608699 non-null  object
#  7   City               608699 non-null  object
#  8   O3 Mean            608699 non-null  float64
#  9   O3 1st Max Value   608699 non-null  float64
#  10  O3 1st Max Hour    608699 non-null  int64
#  11  O3 AQI             608699 non-null  int64
#  12  CO Mean            608699 non-null  float64
#  13  CO 1st Max Value   608699 non-null  float64
#  14  CO 1st Max Hour    608699 non-null  int64
#  15  CO AQI             608699 non-null  float64
#  16  SO2 Mean           608699 non-null  float64
#  17  SO2 1st Max Value  608699 non-null  float64
#  18  SO2 1st Max Hour   608699 non-null  int64
#  19  SO2 AQI            608699 non-null  float64
#  20  NO2 Mean           608699 non-null  float64
#  21  NO2 1st Max Value  608699 non-null  float64
#  22  NO2 1st Max Hour   608699 non-null  int64
#  23  NO2 AQI            608699 non-null  int64
# dtypes: float64(10), int64(9), object(5)
# memory usage: 111.5+ MB

# %% [markdown]
# ### Missing value

# %%
us_pollution.isnull().sum()
# Out:
# Date                 0
# Year                 0
# Month                0
# Day                  0
# Address              0
# State                0
# County               0
# City                 0
# O3 Mean              0
# O3 1st Max Value     0
# O3 1st Max Hour      0
# O3 AQI               0
# CO Mean              0
# CO 1st Max Value     0
# CO 1st Max Hour      0
# CO AQI               0
# SO2 Mean             0
# SO2 1st Max Value    0
# SO2 1st Max Hour     0
# SO2 AQI              0
# NO2 Mean             0
# NO2 1st Max Value    0
# NO2 1st Max Hour     0
# NO2 AQI              0
# dtype: int64

# %%
mis_values_sum = sum(us_pollution.isnull().sum())
print(f"There are {mis_values_sum} missing values.")
# Out:
# There are 0 missing values.

# %%
# Convert string to datetime64
us_pollution['Date'] = pd.to_datetime(us_pollution['Date'])

# %% [markdown]
# ### How many Cities?

# %%
cities = us_pollution['City'].value_counts()
print(f'There are {len(cities)} cities in the dataset.')
print(cities.index)
# Out:
# There are 148 cities in the dataset.
# Index(['Not in a city', 'Los Angeles', 'New York', 'Phoenix', 'Rubidoux',
#        'North Little Rock', 'Houston', 'Charlotte', 'El Paso', 'Washington',
#        ...
#        'West Los Angeles', 'Athens', 'Ladue', 'Ferguson', 'St. Ann', 'Kenner',
#        'Bakersfield', 'Dentsville (Dents)', 'Memphis', 'Roosevelt'],
#       dtype='object', length=148)

# %% [markdown]
# ### Which cities are most polluted?

# %%
from IPython.display import display_html
def display_side_by_side(dfs,color):
    html_str=''
    for df in dfs:
        df = df[:10].style.set_precision(2).background_gradient(cmap=color)
        html_str += df.render()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

def max_polluted_city_overall(pollutant):
    pollutant_col = f'{pollutant} AQI'
    ordered = us_pollution[[pollutant_col,'City']].groupby(["City"]).mean().sort_values(by=pollutant_col,ascending=False).reset_index()
    ordered[pollutant_col] = round(ordered[pollutant_col],2)
    return ordered

def max_polluted_city_recent_five(pollutant):
    pollutant_col = f'{pollutant} AQI'
    ordered = us_pollution[us_pollution['Year'] > 2015][[pollutant_col,'City']].groupby(["City"]).mean().sort_values(by=pollutant_col,ascending=False).reset_index()
    ordered[pollutant_col] = round(ordered[pollutant_col],2)
    return ordered

def max_polluted_city_old_ten(pollutant):
    pollutant_col = f'{pollutant} AQI'
    ordered = us_pollution[us_pollution['Year'] < 2011][[pollutant_col,'City']].groupby(["City"]).mean().sort_values(by=pollutant_col,ascending=False).reset_index()
    ordered[pollutant_col] = round(ordered[pollutant_col],2)
    return ordered


def display_max_polluted_city_overall():
    o3_city = max_polluted_city_overall('O3')
    co_city = max_polluted_city_overall('CO')
    so2_city = max_polluted_city_overall('SO2')
    no3_city = max_polluted_city_overall('NO2')
    citysets=o3_city, co_city, so2_city, no3_city
    display_side_by_side(citysets,'OrRd')

def display_max_polluted_city_recent_five():
    o3_city = max_polluted_city_recent_five('O3')
    co_city = max_polluted_city_recent_five('CO')
    so2_city = max_polluted_city_recent_five('SO2')
    no3_city = max_polluted_city_recent_five('NO2')
    citysets=o3_city, co_city, so2_city, no3_city
    display_side_by_side(citysets,'OrRd')

def city_dif(pollutant):
    pollutant_col = f'{pollutant} AQI'
    pollutant_change = f'{pollutant} Change'
    city = max_polluted_city_recent_five(pollutant)
    city_old = max_polluted_city_old_ten(pollutant)
    dif = city
    dif[pollutant_change] = city[pollutant_col] - city_old[pollutant_col]
    return dif


def city_increase(pollutant):
    dif = city_dif(pollutant)
    pollutant_col = f'{pollutant} AQI'
    pollutant_change = f'{pollutant} Change'
    increase = dif.sort_values(by=pollutant_change,ascending=False).reset_index()
    increase = increase[['City', pollutant_col, pollutant_change]]
    return increase


def city_decrease(pollutant):
    dif = city_dif(pollutant)
    pollutant_col = f'{pollutant} AQI'
    pollutant_change = f'{pollutant} Change'
    decrease = dif.sort_values(by=pollutant_change,ascending=True).reset_index()
    decrease = decrease[['City', pollutant_col, pollutant_change]]
    return decrease


def display_city_increase():
    o3_increase = city_increase('O3')
    co_increase = city_increase('CO')
    so2_increase = city_increase('SO2')
    no3_increase = city_increase('NO2')
    increasesets=o3_increase,co_increase,so2_increase,no3_increase
    display_side_by_side(increasesets,'OrRd')

    
def display_city_decrease():
    o3_decrease = city_decrease('O3')
    co_decrease = city_decrease('CO')
    so2_decrease = city_decrease('SO2')
    no3_decrease = city_decrease('NO2')
    decreasesets=o3_decrease,co_decrease,so2_decrease,no3_decrease
    display_side_by_side(decreasesets,'GnBu_r')

# %%
display_max_polluted_city_overall()
# Out:
# <style type="text/css">
# #T_ae40c_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_ae40c_row1_col1 {
#   background-color: #8c0000;
#   color: #f1f1f1;
# }
# #T_ae40c_row2_col1 {
#   background-color: #db3926;
#   color: #f1f1f1;
# }
# #T_ae40c_row3_col1 {
#   background-color: #f26d4b;
#   color: #f1f1f1;
# }
# #T_ae40c_row4_col1 {
#   background-color: #fdb982;
#   color: #000000;
# }
# #T_ae40c_row5_col1 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_ae40c_row6_col1 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_ae40c_row7_col1 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_ae40c_row8_col1 {
#   background-color: #fff4e5;
#   color: #000000;
# }
# #T_ae40c_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_ae40c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >O3 AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae40c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae40c_row0_col0" class="data row0 col0" >Winston-Salem</td>
#       <td id="T_ae40c_row0_col1" class="data row0 col1" >66.12</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae40c_row1_col0" class="data row1 col0" >Roosevelt</td>
#       <td id="T_ae40c_row1_col1" class="data row1 col1" >65.77</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae40c_row2_col0" class="data row2 col0" >Rubidoux</td>
#       <td id="T_ae40c_row2_col1" class="data row2 col1" >63.08</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae40c_row3_col0" class="data row3 col0" >Fontana</td>
#       <td id="T_ae40c_row3_col1" class="data row3 col1" >61.64</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae40c_row4_col0" class="data row4 col0" >Ashland</td>
#       <td id="T_ae40c_row4_col1" class="data row4 col1" >59.19</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae40c_row5_col0" class="data row5 col0" >Fresno</td>
#       <td id="T_ae40c_row5_col1" class="data row5 col1" >57.45</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae40c_row6_col0" class="data row6 col0" >Victorville</td>
#       <td id="T_ae40c_row6_col1" class="data row6 col1" >57.16</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae40c_row7_col0" class="data row7 col0" >Lancaster</td>
#       <td id="T_ae40c_row7_col1" class="data row7 col1" >55.95</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ae40c_row8_col0" class="data row8 col0" >Sunset Hills</td>
#       <td id="T_ae40c_row8_col1" class="data row8 col1" >55.23</td>
#     </tr>
#     <tr>
#       <th id="T_ae40c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ae40c_row9_col0" class="data row9 col0" >Norristown</td>
#       <td id="T_ae40c_row9_col1" class="data row9 col1" >54.96</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_be468_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_be468_row1_col1 {
#   background-color: #bb0b07;
#   color: #f1f1f1;
# }
# #T_be468_row2_col1 {
#   background-color: #fdac76;
#   color: #000000;
# }
# #T_be468_row3_col1 {
#   background-color: #fdbd86;
#   color: #000000;
# }
# #T_be468_row4_col1 {
#   background-color: #fdc089;
#   color: #000000;
# }
# #T_be468_row5_col1 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_be468_row6_col1 {
#   background-color: #fee0b7;
#   color: #000000;
# }
# #T_be468_row7_col1 {
#   background-color: #fff0db;
#   color: #000000;
# }
# #T_be468_row8_col1 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_be468_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_be468_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >CO AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be468_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be468_row0_col0" class="data row0 col0" >Hawthorne</td>
#       <td id="T_be468_row0_col1" class="data row0 col1" >17.14</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be468_row1_col0" class="data row1 col0" >Bakersfield</td>
#       <td id="T_be468_row1_col1" class="data row1 col1" >16.07</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be468_row2_col0" class="data row2 col0" >San Diego</td>
#       <td id="T_be468_row2_col1" class="data row2 col1" >13.09</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be468_row3_col0" class="data row3 col0" >Calexico</td>
#       <td id="T_be468_row3_col1" class="data row3 col1" >12.74</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be468_row4_col0" class="data row4 col0" >Burbank</td>
#       <td id="T_be468_row4_col1" class="data row4 col1" >12.62</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be468_row5_col0" class="data row5 col0" >Scottsdale</td>
#       <td id="T_be468_row5_col1" class="data row5 col1" >11.46</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be468_row6_col0" class="data row6 col0" >Seven Corners</td>
#       <td id="T_be468_row6_col1" class="data row6 col1" >11.42</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be468_row7_col0" class="data row7 col0" >Chula Vista</td>
#       <td id="T_be468_row7_col1" class="data row7 col1" >10.62</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be468_row8_col0" class="data row8 col0" >West Los Angeles</td>
#       <td id="T_be468_row8_col1" class="data row8 col1" >10.60</td>
#     </tr>
#     <tr>
#       <th id="T_be468_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be468_row9_col0" class="data row9 col0" >Chicago</td>
#       <td id="T_be468_row9_col1" class="data row9 col1" >10.20</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_d554a_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_d554a_row1_col1 {
#   background-color: #b50302;
#   color: #f1f1f1;
# }
# #T_d554a_row2_col1 {
#   background-color: #bd0e09;
#   color: #f1f1f1;
# }
# #T_d554a_row3_col1 {
#   background-color: #f06849;
#   color: #f1f1f1;
# }
# #T_d554a_row4_col1 {
#   background-color: #f2704c;
#   color: #f1f1f1;
# }
# #T_d554a_row5_col1 {
#   background-color: #f67b51;
#   color: #f1f1f1;
# }
# #T_d554a_row6_col1 {
#   background-color: #f88154;
#   color: #f1f1f1;
# }
# #T_d554a_row7_col1 {
#   background-color: #fee4bf;
#   color: #000000;
# }
# #T_d554a_row8_col1 {
#   background-color: #fff3e2;
#   color: #000000;
# }
# #T_d554a_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_d554a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >SO2 AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d554a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d554a_row0_col0" class="data row0 col0" >Reading</td>
#       <td id="T_d554a_row0_col1" class="data row0 col1" >30.06</td>
#     </tr>
#     <tr>
#       <th id="T_d554a_level0_row1" clas

# %%
display_max_polluted_city_recent_five()
# Out:
# <style type="text/css">
# #T_40d2f_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_40d2f_row1_col1 {
#   background-color: #a80000;
#   color: #f1f1f1;
# }
# #T_40d2f_row2_col1 {
#   background-color: #f77d52;
#   color: #f1f1f1;
# }
# #T_40d2f_row3_col1 {
#   background-color: #fdbe87;
#   color: #000000;
# }
# #T_40d2f_row4_col1 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_40d2f_row5_col1 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_40d2f_row6_col1 {
#   background-color: #fee2bb;
#   color: #000000;
# }
# #T_40d2f_row7_col1 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_40d2f_row8_col1, #T_40d2f_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_40d2f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >O3 AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40d2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40d2f_row0_col0" class="data row0 col0" >Rubidoux</td>
#       <td id="T_40d2f_row0_col1" class="data row0 col1" >64.20</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40d2f_row1_col0" class="data row1 col0" >Fontana</td>
#       <td id="T_40d2f_row1_col1" class="data row1 col1" >62.33</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40d2f_row2_col0" class="data row2 col0" >Victorville</td>
#       <td id="T_40d2f_row2_col1" class="data row2 col1" >55.68</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40d2f_row3_col0" class="data row3 col0" >Fresno</td>
#       <td id="T_40d2f_row3_col1" class="data row3 col1" >52.17</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40d2f_row4_col0" class="data row4 col0" >Calexico</td>
#       <td id="T_40d2f_row4_col1" class="data row4 col1" >49.07</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40d2f_row5_col0" class="data row5 col0" >Memphis</td>
#       <td id="T_40d2f_row5_col1" class="data row5 col1" >48.84</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40d2f_row6_col0" class="data row6 col0" >Phoenix</td>
#       <td id="T_40d2f_row6_col1" class="data row6 col1" >48.48</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40d2f_row7_col0" class="data row7 col0" >Midvale</td>
#       <td id="T_40d2f_row7_col1" class="data row7 col1" >46.92</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40d2f_row8_col0" class="data row8 col0" >Albuquerque</td>
#       <td id="T_40d2f_row8_col1" class="data row8 col1" >45.34</td>
#     </tr>
#     <tr>
#       <th id="T_40d2f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40d2f_row9_col0" class="data row9 col0" >Reno</td>
#       <td id="T_40d2f_row9_col1" class="data row9 col1" >45.31</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_7aa20_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_7aa20_row1_col1 {
#   background-color: #8c0000;
#   color: #f1f1f1;
# }
# #T_7aa20_row2_col1 {
#   background-color: #ae0000;
#   color: #f1f1f1;
# }
# #T_7aa20_row3_col1 {
#   background-color: #f4764f;
#   color: #f1f1f1;
# }
# #T_7aa20_row4_col1 {
#   background-color: #fdbe87;
#   color: #000000;
# }
# #T_7aa20_row5_col1 {
#   background-color: #fdce98;
#   color: #000000;
# }
# #T_7aa20_row6_col1, #T_7aa20_row7_col1 {
#   background-color: #fdd7a4;
#   color: #000000;
# }
# #T_7aa20_row8_col1 {
#   background-color: #fff4e5;
#   color: #000000;
# }
# #T_7aa20_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_7aa20_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >CO AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aa20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7aa20_row0_col0" class="data row0 col0" >Oakland</td>
#       <td id="T_7aa20_row0_col1" class="data row0 col1" >7.14</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7aa20_row1_col0" class="data row1 col0" >Sunrise Manor</td>
#       <td id="T_7aa20_row1_col1" class="data row1 col1" >7.09</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7aa20_row2_col0" class="data row2 col0" >Phoenix</td>
#       <td id="T_7aa20_row2_col1" class="data row2 col1" >6.97</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7aa20_row3_col0" class="data row3 col0" >Calexico</td>
#       <td id="T_7aa20_row3_col1" class="data row3 col1" >6.51</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7aa20_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_7aa20_row4_col1" class="data row4 col1" >6.20</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7aa20_row5_col0" class="data row5 col0" >El Paso</td>
#       <td id="T_7aa20_row5_col1" class="data row5 col1" >6.08</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7aa20_row6_col0" class="data row6 col0" >Fresno</td>
#       <td id="T_7aa20_row6_col1" class="data row6 col1" >6.01</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7aa20_row7_col0" class="data row7 col0" >Los Angeles</td>
#       <td id="T_7aa20_row7_col1" class="data row7 col1" >6.01</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7aa20_row8_col0" class="data row8 col0" >Winter Park</td>
#       <td id="T_7aa20_row8_col1" class="data row8 col1" >5.71</td>
#     </tr>
#     <tr>
#       <th id="T_7aa20_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7aa20_row9_col0" class="data row9 col0" >Vallejo</td>
#       <td id="T_7aa20_row9_col1" class="data row9 col1" >5.67</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_787aa_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_787aa_row1_col1, #T_787aa_row2_col1 {
#   background-color: #fdd9aa;
#   color: #000000;
# }
# #T_787aa_row3_col1 {
#   background-color: #feeacc;
#   color: #000000;
# }
# #T_787aa_row4_col1 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_787aa_row5_col1 {
#   background-color: #feeed7;
#   color: #000000;
# }
# #T_787aa_row6_col1 {
#   background-color: #fff1dd;
#   color: #000000;
# }
# #T_787aa_row7_col1 {
#   background-color: #fff4e5;
#   color: #000000;
# }
# #T_787aa_row8_col1 {
#   background-color: #fff5e7;
#   color: #000000;
# }
# #T_787aa_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_787aa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >SO2 AQI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_787aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_787aa_row0_col0" class="data row0 col0" >Fairbanks</td>
#       <td id="T_787aa_row0_col1" class="data row0 col1" >13.37</td>
#     </tr>
#     <tr>
#       <th id="T_787aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_787aa_row1_col0" class="data row1 col0" >Cleveland</td>
#       <td id="T_787aa_row1_col1" class="data row1 col1" >4.80</td>
#     </tr>

# %%
display_city_increase()
# Out:
# <style type="text/css">
# #T_6d112_row0_col1 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_6d112_row0_col2, #T_6d112_row1_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_6d112_row1_col2 {
#   background-color: #b80604;
#   color: #f1f1f1;
# }
# #T_6d112_row2_col1 {
#   background-color: #fff6ea;
#   color: #000000;
# }
# #T_6d112_row2_col2, #T_6d112_row3_col2 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_6d112_row3_col1, #T_6d112_row5_col1 {
#   background-color: #fff2e1;
#   color: #000000;
# }
# #T_6d112_row4_col1, #T_6d112_row9_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_6d112_row4_col2 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_6d112_row5_col2 {
#   background-color: #feefda;
#   color: #000000;
# }
# #T_6d112_row6_col1 {
#   background-color: #fff1de;
#   color: #000000;
# }
# #T_6d112_row6_col2 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_6d112_row7_col1 {
#   background-color: #fff4e4;
#   color: #000000;
# }
# #T_6d112_row7_col2 {
#   background-color: #fff3e2;
#   color: #000000;
# }
# #T_6d112_row8_col1 {
#   background-color: #fff5e7;
#   color: #000000;
# }
# #T_6d112_row8_col2 {
#   background-color: #fff7eb;
#   color: #000000;
# }
# #T_6d112_row9_col1 {
#   background-color: #feefd9;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_6d112_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >O3 AQI</th>
#       <th class="col_heading level0 col2" >O3 Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d112_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d112_row0_col0" class="data row0 col0" >Fontana</td>
#       <td id="T_6d112_row0_col1" class="data row0 col1" >62.33</td>
#       <td id="T_6d112_row0_col2" class="data row0 col2" >-1.30</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d112_row1_col0" class="data row1 col0" >Rubidoux</td>
#       <td id="T_6d112_row1_col1" class="data row1 col1" >64.20</td>
#       <td id="T_6d112_row1_col2" class="data row1 col2" >-1.92</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d112_row2_col0" class="data row2 col0" >Vallejo</td>
#       <td id="T_6d112_row2_col1" class="data row2 col1" >31.45</td>
#       <td id="T_6d112_row2_col2" class="data row2 col2" >-5.29</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d112_row3_col0" class="data row3 col0" >Cornwall</td>
#       <td id="T_6d112_row3_col1" class="data row3 col1" >32.48</td>
#       <td id="T_6d112_row3_col2" class="data row3 col2" >-5.29</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d112_row4_col0" class="data row4 col0" >Boston</td>
#       <td id="T_6d112_row4_col1" class="data row4 col1" >31.10</td>
#       <td id="T_6d112_row4_col2" class="data row4 col2" >-5.32</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d112_row5_col0" class="data row5 col0" >Cleveland</td>
#       <td id="T_6d112_row5_col1" class="data row5 col1" >32.51</td>
#       <td id="T_6d112_row5_col2" class="data row5 col2" >-5.40</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d112_row6_col0" class="data row6 col0" >San Jose</td>
#       <td id="T_6d112_row6_col1" class="data row6 col1" >32.78</td>
#       <td id="T_6d112_row6_col2" class="data row6 col2" >-5.44</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d112_row7_col0" class="data row7 col0" >Newark</td>
#       <td id="T_6d112_row7_col1" class="data row7 col1" >32.10</td>
#       <td id="T_6d112_row7_col2" class="data row7 col2" >-5.52</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d112_row8_col0" class="data row8 col0" >Houston</td>
#       <td id="T_6d112_row8_col1" class="data row8 col1" >31.64</td>
#       <td id="T_6d112_row8_col2" class="data row8 col2" >-5.67</td>
#     </tr>
#     <tr>
#       <th id="T_6d112_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d112_row9_col0" class="data row9 col0" >Not in a city</td>
#       <td id="T_6d112_row9_col1" class="data row9 col1" >33.41</td>
#       <td id="T_6d112_row9_col2" class="data row9 col2" >-5.69</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_ebd61_row0_col1 {
#   background-color: #fdb881;
#   color: #000000;
# }
# #T_ebd61_row0_col2, #T_ebd61_row9_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_ebd61_row1_col1 {
#   background-color: #f88154;
#   color: #f1f1f1;
# }
# #T_ebd61_row1_col2 {
#   background-color: #930000;
#   color: #f1f1f1;
# }
# #T_ebd61_row2_col1 {
#   background-color: #fdc68f;
#   color: #000000;
# }
# #T_ebd61_row2_col2 {
#   background-color: #b80604;
#   color: #f1f1f1;
# }
# #T_ebd61_row3_col1 {
#   background-color: #fc9560;
#   color: #000000;
# }
# #T_ebd61_row3_col2 {
#   background-color: #d32a1b;
#   color: #f1f1f1;
# }
# #T_ebd61_row4_col1 {
#   background-color: #fdb27b;
#   color: #000000;
# }
# #T_ebd61_row4_col2 {
#   background-color: #e7533a;
#   color: #f1f1f1;
# }
# #T_ebd61_row5_col1 {
#   background-color: #a50000;
#   color: #f1f1f1;
# }
# #T_ebd61_row5_col2 {
#   background-color: #f4764f;
#   color: #f1f1f1;
# }
# #T_ebd61_row6_col1, #T_ebd61_row9_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_ebd61_row6_col2, #T_ebd61_row7_col2 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_ebd61_row7_col1 {
#   background-color: #fff6e9;
#   color: #000000;
# }
# #T_ebd61_row8_col1 {
#   background-color: #910000;
#   color: #f1f1f1;
# }
# #T_ebd61_row8_col2 {
#   background-color: #fdd6a3;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_ebd61_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >CO AQI</th>
#       <th class="col_heading level0 col2" >CO Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebd61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebd61_row0_col0" class="data row0 col0" >Waco</td>
#       <td id="T_ebd61_row0_col1" class="data row0 col1" >2.04</td>
#       <td id="T_ebd61_row0_col2" class="data row0 col2" >-2.39</td>
#     </tr>
#     <tr>
#       <th id="T_ebd61_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebd61_row1_col0" class="data row1 col0" >Hampton</td>
#       <td id="T_ebd61_row1_col1" class="data row1 col1" >2.14</td>
#       <td id="T_ebd61_row1_col2" class="data row1 col2" >-2.40</td>
#     </tr>
#     <tr>
#       <th id="T_ebd61_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebd61_row2_col0" class="data row2 col0" >Presque Isle</td>
#       <td id="T_ebd61_row2_col1" class="data row2 col1" >2.00</td>
#       <td id="T_ebd61_row2_col2" class="data row2 col2" >-2.42</td>
#     </tr>
#     <tr>
#       <th id="T_ebd61_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ebd61_row3_col0" class="data row3 col0" >Bismarck</td>
#       <td id="T_ebd61_row3_col1" class="data row3 col1" >2.10</td>
#       <td id="T_ebd61_row3_col2" class="data row3 col2" >-2.44</td>
#     </tr>
#     <tr>
#       <th id="T_ebd61_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ebd61_row4_col0" class="data row4 col0" >Londonderry</td>
#       <td id="T_ebd61_row4_col1" class="data row4 col1" >2.05</td>
#       <td id="T_ebd61_row4_col2" class="data row4 col2" >-2.46</td>
#     </tr>
#     <tr>
#       <th id="T_ebd61_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ebd61_row5_col0" class="data row5 col0" >Sioux Falls</td>
#       <td id="T_ebd61_row5_col1" class="data row5 col1" >2.38</td>
#       <td id="T_ebd61_row5_col2" class="data row5 col2" >-2.48</td>
#     </tr>
#     <tr>
#       <t

# %%
display_city_decrease()
# Out:
# <style type="text/css">
# #T_f10bc_row0_col1, #T_f10bc_row0_col2 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_f10bc_row1_col1 {
#   background-color: #0b6cae;
#   color: #f1f1f1;
# }
# #T_f10bc_row1_col2 {
#   background-color: #9cd9b9;
#   color: #000000;
# }
# #T_f10bc_row2_col1 {
#   background-color: #1d7eb7;
#   color: #f1f1f1;
# }
# #T_f10bc_row2_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_f10bc_row3_col1 {
#   background-color: #2586bb;
#   color: #f1f1f1;
# }
# #T_f10bc_row3_col2 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_f10bc_row4_col1 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_f10bc_row4_col2 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_f10bc_row5_col1, #T_f10bc_row5_col2 {
#   background-color: #f1f9ea;
#   color: #000000;
# }
# #T_f10bc_row6_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_f10bc_row6_col2 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_f10bc_row7_col1 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_f10bc_row7_col2 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_f10bc_row8_col1, #T_f10bc_row9_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_f10bc_row8_col2 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_f10bc_row9_col1 {
#   background-color: #d0ecc9;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_f10bc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >O3 AQI</th>
#       <th class="col_heading level0 col2" >O3 Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f10bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f10bc_row0_col0" class="data row0 col0" >Fairbanks</td>
#       <td id="T_f10bc_row0_col1" class="data row0 col1" >19.90</td>
#       <td id="T_f10bc_row0_col2" class="data row0 col2" >-14.95</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f10bc_row1_col0" class="data row1 col0" >Lompoc</td>
#       <td id="T_f10bc_row1_col1" class="data row1 col1" >23.42</td>
#       <td id="T_f10bc_row1_col2" class="data row1 col2" >-11.77</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f10bc_row2_col0" class="data row2 col0" >Eureka</td>
#       <td id="T_f10bc_row2_col1" class="data row2 col1" >25.01</td>
#       <td id="T_f10bc_row2_col2" class="data row2 col2" >-10.52</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f10bc_row3_col0" class="data row3 col0" >Oakland</td>
#       <td id="T_f10bc_row3_col1" class="data row3 col1" >25.68</td>
#       <td id="T_f10bc_row3_col2" class="data row3 col2" >-9.93</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f10bc_row4_col0" class="data row4 col0" >Northbrook</td>
#       <td id="T_f10bc_row4_col1" class="data row4 col1" >44.91</td>
#       <td id="T_f10bc_row4_col2" class="data row4 col2" >-9.88</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f10bc_row5_col0" class="data row5 col0" >Tucson</td>
#       <td id="T_f10bc_row5_col1" class="data row5 col1" >44.41</td>
#       <td id="T_f10bc_row5_col2" class="data row5 col2" >-9.75</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f10bc_row6_col0" class="data row6 col0" >Dentsville (Dents)</td>
#       <td id="T_f10bc_row6_col1" class="data row6 col1" >39.62</td>
#       <td id="T_f10bc_row6_col2" class="data row6 col2" >-9.70</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f10bc_row7_col0" class="data row7 col0" >Capitan</td>
#       <td id="T_f10bc_row7_col1" class="data row7 col1" >39.94</td>
#       <td id="T_f10bc_row7_col2" class="data row7 col2" >-9.63</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f10bc_row8_col0" class="data row8 col0" >Albuquerque</td>
#       <td id="T_f10bc_row8_col1" class="data row8 col1" >45.34</td>
#       <td id="T_f10bc_row8_col2" class="data row8 col2" >-9.62</td>
#     </tr>
#     <tr>
#       <th id="T_f10bc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f10bc_row9_col0" class="data row9 col0" >Hampton</td>
#       <td id="T_f10bc_row9_col1" class="data row9 col1" >39.53</td>
#       <td id="T_f10bc_row9_col2" class="data row9 col2" >-9.56</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# <style type="text/css">
# #T_1b565_row0_col1, #T_1b565_row8_col2, #T_1b565_row9_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_1b565_row0_col2, #T_1b565_row9_col1 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_1b565_row1_col1 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_1b565_row1_col2 {
#   background-color: #085497;
#   color: #f1f1f1;
# }
# #T_1b565_row2_col1 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_1b565_row2_col2 {
#   background-color: #2081b8;
#   color: #f1f1f1;
# }
# #T_1b565_row3_col1 {
#   background-color: #95d6bb;
#   color: #000000;
# }
# #T_1b565_row3_col2 {
#   background-color: #5ebcce;
#   color: #000000;
# }
# #T_1b565_row4_col1 {
#   background-color: #3395c3;
#   color: #f1f1f1;
# }
# #T_1b565_row4_col2 {
#   background-color: #8fd4bd;
#   color: #000000;
# }
# #T_1b565_row5_col1 {
#   background-color: #4aafd1;
#   color: #f1f1f1;
# }
# #T_1b565_row5_col2 {
#   background-color: #94d5bc;
#   color: #000000;
# }
# #T_1b565_row6_col1, #T_1b565_row7_col1 {
#   background-color: #2687bb;
#   color: #f1f1f1;
# }
# #T_1b565_row6_col2 {
#   background-color: #b2e1b9;
#   color: #000000;
# }
# #T_1b565_row7_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_1b565_row8_col1 {
#   background-color: #084889;
#   color: #f1f1f1;
# }
# </style>
# <table style="display:inline" id="T_1b565_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >CO AQI</th>
#       <th class="col_heading level0 col2" >CO Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b565_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b565_row0_col0" class="data row0 col0" >Oakland</td>
#       <td id="T_1b565_row0_col1" class="data row0 col1" >7.14</td>
#       <td id="T_1b565_row0_col2" class="data row0 col2" >-10.00</td>
#     </tr>
#     <tr>
#       <th id="T_1b565_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b565_row1_col0" class="data row1 col0" >Sunrise Manor</td>
#       <td id="T_1b565_row1_col1" class="data row1 col1" >7.09</td>
#       <td id="T_1b565_row1_col2" class="data row1 col2" >-9.72</td>
#     </tr>
#     <tr>
#       <th id="T_1b565_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b565_row2_col0" class="data row2 col0" >Phoenix</td>
#       <td id="T_1b565_row2_col1" class="data row2 col1" >6.97</td>
#       <td id="T_1b565_row2_col2" class="data row2 col2" >-9.10</td>
#     </tr>
#     <tr>
#       <th id="T_1b565_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b565_row3_col0" class="data row3 col0" >Calexico</td>
#       <td id="T_1b565_row3_col1" class="data row3 col1" >6.51</td>
#       <td id="T_1b565_row3_col2" class="data row3 col2" >-8.21</td>
#     </tr>
#     <tr>
#       <th id="T_1b565_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b565_row4_col0" class="data row4 col0" >El Paso</td>
#       <td id="T_1b565_row4_col1" class="data row4 col1" >6.08</td>
#       <td id="T_1b565_row4_col2" class="data row4 col2" >-7.64</td>
#     </tr>
#     <tr>
#       <th id="T_1b565_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b565_row5_col0" class="data row5 col0" >Long Beach</td>
#       <td id="T_1b565_row5_col1" class="data row5 col1" >6.20</td>
#       <td id="T_1b565_row5_col2" class="data row5 col2" >-7.59</td>
#     </tr>
#     <t

# %% [markdown]
# ### Pollution in City

# %%
def plotcity(city):
    city_data = us_pollution[us_pollution['City'] == city]
    select_city_data = city_data[['Date',
                                    'O3 AQI', 
                                    'CO AQI', 
                                    'SO2 AQI',
                                    'NO2 AQI']].copy(deep=False)

    select_city_data.set_index('Date', inplace=True)
    plot_title=f'{city} Pollution'
    select_city_data.plot(figsize=(10,4), title=plot_title,xlabel='Time')

# %%
largest_cities = ['New York', 'Los Angeles', 'Houston']
for city in largest_cities:
    plotcity(city)

# %%
def plot_over_year_month(pollutant):
    pollutant_col = f'{pollutant} AQI'
    fig, axes = plt.subplots(1, 2, figsize=(14,6), dpi= 80)
    sns.boxplot(x='Year', y=pollutant_col, data=us_pollution[us_pollution['Year'] > 2010], ax=axes[0])
    sns.pointplot(x='Month', y=pollutant_col, data=us_pollution)
    axes[0].set_title('US Year-wise Box Plot', fontsize=18); 
    axes[1].set_title('US Month-wise Plot', fontsize=18)

    
def plot_year_month(city, pollutant):
    city_data = us_pollution[us_pollution['City'] == city]
    pollutant_col = f'{pollutant} AQI'
    select_city_data = city_data[['Date', 'Year', 'Month', pollutant_col]].copy(deep=False)
    select_city_data.set_index('Date', inplace=True)
    plot_title=f'{city} Pollution'
    fig, axes = plt.subplots(1, 2, figsize=(14,6), dpi= 80)
    sns.boxplot(x='Year', y=pollutant_col, data=select_city_data[select_city_data['Year'] > 2010], ax=axes[0])
    sns.pointplot(x='Month', y=pollutant_col, data=select_city_data)
    axes[0].set_title(f'{city} Year-wise Box Plot', fontsize=18); 
    axes[1].set_title(f'{city} Month-wise Plot', fontsize=18)

# %%
# pollutants = ['O3', 'CO', 'SO2','NO2']
# for pollutant in pollutants:
#     plot_over_year_month(pollutant)
plot_over_year_month('O3')

# %%
plot_over_year_month('CO')

# %%
plot_over_year_month('SO2')

# %%
plot_over_year_month('NO2')

# %% [markdown]
# ### Plot a City such as New York

# %%
plot_year_month('New York', 'O3')

# %%
plot_year_month('New York', 'CO')

# %%
plot_year_month('New York', 'SO2')

# %%
plot_year_month('New York', 'NO2')

# %% [markdown]
# ### Heat map

# %%
city_data = pd.read_csv('uscities.csv')

# %%
city_data
# Out:
#               city   city_ascii state_id  state_name  county_fips  \
# 0         New York     New York       NY    New York        36061
# 1      Los Angeles  Los Angeles       CA  California         6037
# 2          Chicago      Chicago       IL    Illinois        17031
# 3            Miami        Miami       FL     Florida        12086
# 4           Dallas       Dallas       TX       Texas        48113
# ...            ...          ...      ...         ...          ...
# 28333        Gross        Gross       NE    Nebraska        31015
# 28334       Lotsee       Lotsee       OK    Oklahoma        40143
# 28335    The Ranch    The Ranch       MN   Minnesota        27087
# 28336     Shamrock     Shamrock       OK    Oklahoma        40037
# 28337       Monowi       Monowi       NE    Nebraska        31015
#
#        county_name      lat       lng  population  density   source  military  \
# 0         New York  40.6943  -73.9249    18713220    10715  polygon     False
# 1      Los Angeles  34.1139 -118.4068    12750807     3276  polygon     False
# 2             Cook  41.8373  -87.6862     8604203     4574  polygon     False
# 3       Miami-Dade  25.7839  -80.2102     6445545     5019  polygon     False
# 4           Dallas  32.7936  -96.7662     5743938     1526  polygon     False
# ...            ...      ...       ...         ...      ...      ...       ...
# 28333         Boyd  42.9461  -98.5697           2        6  polygon     False
# 28334        Tulsa  36.1334  -96.2091           2       39  polygon     False
# 28335     Mahnomen  47.3198  -95.6952           2        2  polygon     False
# 28336        Creek  35.9113  -96.5772           2        2  polygon     False
# 28337         Boyd  42.8307  -98.3296           1        1  polygon     False
#
#        incorporated             timezone  ranking  \
# 0              True     America/New_York        1
# 1              True  America/Los_Angeles        1
# 2              True      America/Chicago        1
# 3              True     America/New_York        1
# 4              True      America/Chicago        1
# ...             ...                  ...      ...
# 28333          True      America/Chicago        3
# 28334          True      America/Chicago        3
# 28335          True      America/Chicago        3
# 28336          True      America/Chicago        3
# 28337          True      America/Chicago        3
#
#                                                     zips          id
# 0      11229 11226 11225 11224 11222 11221 11220 1138...  1840034016
# 1      90291 90293 90292 91316 91311 90037 90031 9000...  1840020491
# 2      60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3      33129 33125 33126 33127 33128 33149 33144 3314...  1840015149
# 4      75287 75098 75233 75254 75251 75252 75253 7503...  1840019440
# ...                                                  ...         ...
# 28333                                              68719  1840011032
# 28334                                              74063  1840021674
# 28335                                              56557  1840039629
# 28336                                              74068  1840022701
# 28337                                              68746  1840011034
#
# [28338 rows x 17 columns]

# %%
city_list = list(cities.index)
def plot_heat_map(pollutant, cityindex):
    pollutant_col = f'{pollutant} AQI'
    heat_map_data = pd.DataFrame(columns=('City',
                                         pollutant,
                                         'lat',
                                         'lng'), dtype=object)
    for city in cityindex:
        city_statis=city_data[city_data['city']== city]
        if not city_statis.empty:
            city_lat = float(city_statis.head(1)['lat'])
            city_lng = float(city_statis.head(1)['lng'])
            mean = us_pollution[us_pollution['City']== city][pollutant_col].mean()
            new_heat_map_data = pd.DataFrame(np.insert(heat_map_data.values,
                                                          len(heat_map_data.index),
                                                          values=[city,
                                                                  mean,
                                                                  city_lat,
                                                                  city_lng,
                                                                  ],
                                                          axis=0))
            new_heat_map_data.columns = heat_map_data.columns
            heat_map_data = new_heat_map_data
    heat_map_data=heat_map_data[['lat','lng',pollutant]]
    map_van = folium.Map(location = [41.8373, -100], zoom_start = 4)
    HeatMap(heat_map_data).add_to(map_van)
    return map_van

# %%
plot_heat_map('NO2', city_list)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e61e34a82444995b0b0e159f63bc2a3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e61e34a82444995b0b0e159f63bc2a3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e61e34a82444995b0b0e159f63bc2a3c = L.map(
#                 &quot;map_e61e34a82444995b0b0e159f63bc2a3c&quot;,
#                 {
#                     center: [41.8373, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_768acd94d81e54963e0d9658695b5673 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e61e34a82444995b0b0e159f63bc2a3c);
#
#
#             var heat_map_001ce0272ff707c3eadbf4c3fbb4c9d3 = L.heatLayer(
#                 [[34.1139, -118.4068, 33.64232176050849], [40.6943, -73.9249, 33.163131085176346], [33.5722, -112.0891, 37.36011814601636], [34.7808, -92.2371, 20.636195922885342], [29.7863, -95.3889, 24.591180088956186], [35.208, -80.8304, 21.39011716760061], [31.8479, -106.4309, 29.115187011919442], [38.9047, -77.0163, 27.004929886064854], [41.5563, -90.6052, 11.906188281764319], [45.5372, -122.65, 17.21809240622141], [37.9722, -122.0016, 16.811778144434573], [38.1133, -122.2358, 18.085054832950778], [32.1545, -110.8
991810737], [37.7903, -122.2165, 25.116391184573004], [40.7245, -74.1725, 32.305901337021666], [41.5725, -93.6105, 35.73039215686274], [40.1384, -79.9002, 44.761201501877345], [41.8065, -71.3565, 38.86537966537966], [42.1292, -87.8353, 34.81402040282501], [32.8017, -116.9605, 43.24414270500532], [39.5497, -119.8483, 43.69447424892704], [35.1053, -106.6464, 44.52241610738255], [43.5397, -96.732, 36.595251091703055], [32.6281, -117.0145, 41.98983516483516], [37.7562, -122.443, 24.490424646128226], [39.0394, -76.9211, 38.043660789252726], [29.6898, -95.1151, 35.601239087580964], [31.5598, -97.1881, 39.347543760587236], [39.1413, -84.5061, 37.67993079584775], [34.436, -119.8596, 36.42125865703102], [37.577, -77.3865, 37.05894929749542], [38.0182, -121.8964, 34.74257728803183], [36.5572, -82.2154, 49.1615625], [42.1168, -80.0733, 42.481980464802966], [41.8445, -87.7593, 35.974035608308604], [35.8325, -78.6435, 37.676077265973255], [38.9436, -77.1943, 40.16797312430011], [38.1663, -85.6485, 39.647731605032405], [47.6211, -122.3244, 26.302727621974643], [40.6148, -112.4777, 38.354281225451686], [34.21, -77.8866, 36.3559804719284], [38.8185, -77.0861, 47.69698205546493], [45.1696, -93.2077, 34.282932891466444], [37.0551, -76.363, 42.73697694278395], [35.4676, -97.5136, 44.66696349065005], [33.6872, -111.8651, 34.85227795674183], [38.8324, -77.196, 45.22242731887402], [33.5277, -86.7987, 38.137431284357824], [40.628, -75.3401, 51.981751824817515], [40.9956, -80.3459, 43.183491062039955], [40.5082, -78.4007, 47.5715795034337], [43.6091, -72.9782, 33.10529100529101], [40.0421, -76.3012, 55.94957537154989], [40.3113, -79.5444, 47.92307692307692], [40.762, -80.3225, 46.25040214477212], [40.2659, -76.4077, 39.483351235230934], [40.1224, -75.3398, 54.961580086580085], [37.2746, -79.8887, 39.09373297002725], [41.4044, -75.6649, 46.66520065970313], [42.9848, -71.4447, 38.223017621145374], [46.8144, -100.7694, 31.471186440677965], [35.8546, -94.9559, 48.00934579439252], [64.8353, -147.6534, 19.05211081794195], [33.9146, -1 ...

# %%
    
#     pollutant = 'CO'
#     pollutant_col = f'{pollutant} AQI'
#     heat_map_data = pd.DataFrame(columns=('City',
#                                          'CO',
#                                          'lat',
#                                          'lng'), dtype=object)
#     for city in list_one:
#         city_statis=city_data[city_data['city']== city]
#         if not city_statis.empty:
#             city_lat = float(city_statis.head(1)['lat'])
#             city_lng = float(city_statis.head(1)['lng'])
#             no2_mean = us_pollution[us_pollution['City']== city]['CO AQI'].mean()
#             new_heat_map_data = pd.DataFrame(np.insert(heat_map_data.values,
#                                                           len(heat_map_data.index),
#                                                           values=[city,
#                                                                   no2_mean,
#                                                                   city_lat,
#                                                                   city_lng,
#                                                                   ],
#                                                           axis=0))
#             new_heat_map_data.columns = heat_map_data.columns
#             heat_map_data = new_heat_map_data
#     heat_map_data=heat_map_data[['lat','lng','CO']]
#     map_van = folium.Map(location = [41.8373, -100], zoom_start = 4)
#     HeatMap(heat_map_data).add_to(map_van)
#     map_van
