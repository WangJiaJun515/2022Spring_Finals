# %%
# import the necessary libraries
import matplotlib
import numpy as np
import pandas as pd
import os

# Visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import chart_studio.plotly as py
from IPython.display import display_html
import folium
from folium.plugins import HeatMap

# Increase the default plot size and set the color scheme
plt.rcParams['figure.figsize'] = 12, 8
plt.style.use("fivethirtyeight")# for pretty graphs

# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# Function
import function

# %%
us_pollution = pd.read_csv('pollution_2000_2021.csv')

# %%
us_pollution
# Out:
#               Date  Year  Month  Day                                  Address  \
# 0       2000-01-01  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1       2000-01-02  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2       2000-01-03  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3       2000-01-04  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4       2000-01-05  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# ...            ...   ...    ...  ...                                      ...
# 608694  2021-06-26  2021      6   26    NCore - North Cheyenne Soccer Complex
# 608695  2021-06-27  2021      6   27    NCore - North Cheyenne Soccer Complex
# 608696  2021-06-28  2021      6   28    NCore - North Cheyenne Soccer Complex
# 608697  2021-06-29  2021      6   29    NCore - North Cheyenne Soccer Complex
# 608698  2021-06-30  2021      6   30    NCore - North Cheyenne Soccer Complex
#
# ...

# %%
us_pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608699 entries, 0 to 608698
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               608699 non-null  object
#  1   Year               608699 non-null  int64
#  2   Month              608699 non-null  int64
#  3   Day                608699 non-null  int64
#  4   Address            608699 non-null  object
#  5   State              608699 non-null  object
#  6   County             608699 non-null  object
#  7   City               608699 non-null  object
#  8   O3 Mean            608699 non-null  float64
#  9   O3 1st Max Value   608699 non-null  float64
#  10  O3 1st Max Hour    608699 non-null  int64
#  11  O3 AQI             608699 non-null  int64
#  12  CO Mean            608699 non-null  float64
#  13  CO 1st Max Value   608699 non-null  float64
#  14  CO 1st Max Hour    608699 non-null  int64
# ...

# %% [markdown]
# ### Missing value

# %%
us_pollution.isnull().sum()
# Out:
# Date                 0
# Year                 0
# Month                0
# Day                  0
# Address              0
# State                0
# County               0
# City                 0
# O3 Mean              0
# O3 1st Max Value     0
# O3 1st Max Hour      0
# O3 AQI               0
# CO Mean              0
# CO 1st Max Value     0
# CO 1st Max Hour      0
# CO AQI               0
# SO2 Mean             0
# SO2 1st Max Value    0
# SO2 1st Max Hour     0
# SO2 AQI              0
# NO2 Mean             0
# NO2 1st Max Value    0
# NO2 1st Max Hour     0
# NO2 AQI              0
# dtype: int64

# %%
mis_values_sum = sum(us_pollution.isnull().sum())
print(f"There are {mis_values_sum} missing values.")
# Out:
# There are 0 missing values.

# %%
# Convert string to datetime64
us_pollution['Date'] = pd.to_datetime(us_pollution['Date'])

# %% [markdown]
# ### How many Cities?

# %%
cities = us_pollution['City'].value_counts()
print(f'There are {len(cities)} cities in the dataset.')
print(cities.index)
# Out:
# There are 148 cities in the dataset.
# Index(['Not in a city', 'Los Angeles', 'New York', 'Phoenix', 'Rubidoux',
#        'North Little Rock', 'Houston', 'Charlotte', 'El Paso', 'Washington',
#        ...
#        'West Los Angeles', 'Athens', 'Ladue', 'Ferguson', 'St. Ann', 'Kenner',
#        'Bakersfield', 'Dentsville (Dents)', 'Memphis', 'Roosevelt'],
#       dtype='object', length=148)

# %% [markdown]
# ### Which cities are most polluted?

# %% [markdown]
#  The cities with the worst average air quality in the past 20 years.

# %%
function.display_max_polluted_city_overall(us_pollution)
# Out:
# <style type="text/css">
# #T_e4380_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_e4380_row1_col1 {
#   background-color: #8c0000;
#   color: #f1f1f1;
# }
# #T_e4380_row2_col1 {
#   background-color: #db3926;
#   color: #f1f1f1;
# }
# #T_e4380_row3_col1 {
#   background-color: #f26d4b;
#   color: #f1f1f1;
# }
# #T_e4380_row4_col1 {
#   background-color: #fdb982;
#   color: #000000;
# }
# #T_e4380_row5_col1 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_e4380_row6_col1 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_e4380_row7_col1 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_e4380_row8_col1 {
#   background-color: #fff4e5;
#   color: #000000;
# }
# #T_e4380_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_e4380_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
# ...

# %% [markdown]
# The cities with the worst air quality in the last 5 years.

# %%
function.display_max_polluted_city_recent_five(us_pollution)
# Out:
# <style type="text/css">
# #T_0a6a4_row0_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_0a6a4_row1_col1 {
#   background-color: #a80000;
#   color: #f1f1f1;
# }
# #T_0a6a4_row2_col1 {
#   background-color: #f77d52;
#   color: #f1f1f1;
# }
# #T_0a6a4_row3_col1 {
#   background-color: #fdbe87;
#   color: #000000;
# }
# #T_0a6a4_row4_col1 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_0a6a4_row5_col1 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_0a6a4_row6_col1 {
#   background-color: #fee2bb;
#   color: #000000;
# }
# #T_0a6a4_row7_col1 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_0a6a4_row8_col1, #T_0a6a4_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table style="display:inline" id="T_0a6a4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >O3 AQI</th>
#     </tr>
# ...

# %% [markdown]
# The cities with the highest increase during the past 20 years.

# %%
function.display_city_increase(us_pollution)
# Out:
# <style type="text/css">
# #T_ccdbf_row0_col1 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_ccdbf_row0_col2, #T_ccdbf_row1_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_ccdbf_row1_col2 {
#   background-color: #b80604;
#   color: #f1f1f1;
# }
# #T_ccdbf_row2_col1 {
#   background-color: #fff6ea;
#   color: #000000;
# }
# #T_ccdbf_row2_col2, #T_ccdbf_row3_col2 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_ccdbf_row3_col1, #T_ccdbf_row5_col1 {
#   background-color: #fff2e1;
#   color: #000000;
# }
# #T_ccdbf_row4_col1, #T_ccdbf_row9_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_ccdbf_row4_col2 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_ccdbf_row5_col2 {
#   background-color: #feefda;
#   color: #000000;
# }
# #T_ccdbf_row6_col1 {
#   background-color: #fff1de;
#   color: #000000;
# }
# #T_ccdbf_row6_col2 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_ccdbf_row7_col1 {
# ...

# %% [markdown]
# The cities with the lowest increase during the past 20 years.

# %%
function.display_city_decrease(us_pollution)
# Out:
# <style type="text/css">
# #T_ffb76_row0_col1, #T_ffb76_row0_col2 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_ffb76_row1_col1 {
#   background-color: #0b6cae;
#   color: #f1f1f1;
# }
# #T_ffb76_row1_col2 {
#   background-color: #9cd9b9;
#   color: #000000;
# }
# #T_ffb76_row2_col1 {
#   background-color: #1d7eb7;
#   color: #f1f1f1;
# }
# #T_ffb76_row2_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_ffb76_row3_col1 {
#   background-color: #2586bb;
#   color: #f1f1f1;
# }
# #T_ffb76_row3_col2 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_ffb76_row4_col1 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_ffb76_row4_col2 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_ffb76_row5_col1, #T_ffb76_row5_col2 {
#   background-color: #f1f9ea;
#   color: #000000;
# }
# #T_ffb76_row6_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_ffb76_row6_col2 {
#   background-color: #f3faec;
#   color: #000000;
# ...

# %% [markdown]
# ### Pollution in City

# %% [markdown]
# AQI Plot for several largest cities in the United States, such as 'New York', 'Los Angeles', and 'Houston'.

# %%
largest_cities = ['New York', 'Los Angeles', 'Houston']
for city in largest_cities:
    function.plotcity(city, us_pollution)

# %% [markdown]
# ## Year-wise Box Plot and Month-wise Plot

# %% [markdown]
# Overall year-wise box plots and monthly plots

# %%
pollutants = ['O3', 'CO', 'SO2','NO2']
for pollutant in pollutants:
    function.plot_over_year_month(pollutant, us_pollution)
# plot_over_year_month('O3')

# %% [markdown]
# ### Plot a City such as New York

# %% [markdown]
# The year-wise box plot and monthly plot in a city.

# %%
for pollutant in pollutants:
    function.plot_year_month('New York', pollutant, us_pollution)

# %% [markdown]
# ### Heat map

# %% [markdown]
# The heat maps for each pollutant in the United States.

# %%
city_data = pd.read_csv('uscities.csv')

# %%
city_data
# Out:
#               city   city_ascii state_id  state_name  county_fips  \
# 0         New York     New York       NY    New York        36061
# 1      Los Angeles  Los Angeles       CA  California         6037
# 2          Chicago      Chicago       IL    Illinois        17031
# 3            Miami        Miami       FL     Florida        12086
# 4           Dallas       Dallas       TX       Texas        48113
# ...            ...          ...      ...         ...          ...
# 28333        Gross        Gross       NE    Nebraska        31015
# 28334       Lotsee       Lotsee       OK    Oklahoma        40143
# 28335    The Ranch    The Ranch       MN   Minnesota        27087
# 28336     Shamrock     Shamrock       OK    Oklahoma        40037
# 28337       Monowi       Monowi       NE    Nebraska        31015
#
#        county_name      lat       lng  population  density   source  military  \
# 0         New York  40.6943  -73.9249    18713220    10715  polygon     False
# ...

# %%
city_list = list(cities.index)

# %%
function.plot_heat_map('NO2', city_list, us_pollution, city_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
function.plot_heat_map('SO2', city_list, us_pollution, city_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
function.plot_heat_map('CO', city_list, us_pollution, city_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
function.plot_heat_map('O3', city_list, us_pollution, city_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
